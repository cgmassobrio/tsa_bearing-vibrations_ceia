# %% [markdown]
# # # Aplicación de arquitectura LSTM para muestra 176s
# El problema ahora se encarará empleando redes neuronales de tipo _Long Short-Term Memory_ (LSTM).

# %% [markdown]
# ## Librerías necesarias

# %%
# Librerías principales
import os
import numpy as np
import pandas as pd

# Herramientas para graficar
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import Grid
from matplotlib import ticker
import seaborn as sns

from sklearn.model_selection import train_test_split
from scipy import signal

from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.models import Model
from keras.layers import Input


# Versiones de librerías
print("".join(f"{x[0]}: {x[1]}\n" for x in [
    ("Numpy",np.__version__),
    ("Pandas",pd.__version__),
]))
# Out:
# Numpy: 1.21.6
# Pandas: 1.3.5

# %% [markdown]
# ## Carga del dataset
# Se carga un dataset a la vez, como primer prueba

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/tsa/data'
files_name = 'dataset_176s.csv'

# %%
df = pd.read_csv(os.path.join(path, files_name), index_col='Time')
df.describe()
# Out:
#          Bearing 1
# count  3001.000000
# mean      0.008645
# std       0.633791
# min      -5.000000
# 25%      -0.273000
# 50%      -0.005000
# 75%       0.286000
# max       4.998000

# %%
plt.figure(figsize=(20,4))

plt.plot(df.index, df)
plt.xlim(df.index[0], df.index[-1])
plt.grid()
plt.xlabel('tiempo de muestreo (s)', fontsize=12)
plt.ylabel('desplazamiento ($\mu$m)', fontsize=12)
plt.title(f'Vibraciones alrededor de los 100s', fontsize=14)

plt.show()

# %% [markdown]
# ## Preprocesamiento

# %%
tokens = df['Bearing 1'].tolist()
tokens[:10]
# Out:
# [-0.425, -0.564, -0.84, 0.1, 0.212, 0.264, 0.447, 0.713, -0.081, -1.152]

# %%
time = df.index.tolist()
time[:10]
# Out:
# [176.0,
#  176.00005,
#  176.0001,
#  176.00015,
#  176.0002,
#  176.00024,
#  176.0003,
#  176.00035,
#  176.0004,
#  176.00044]

# %%
# Código para hacer el desfazaje de los tokens
# según el train_len
train_len = 9

sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
# sequences[:5]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 2992

# %% [markdown]
# ## Input y Target

# %%
arr_sequences = np.array(sequences)
X = arr_sequences[:,:-1]
y = arr_sequences[:,-1]

print("Dimensiones input:", X.shape)
print("Dimensiones target:", y.shape)
# Out:
# Dimensiones input: (2992, 8)
# Dimensiones target: (2992,)

# %% [markdown]
# ## Preparación

# %%
# Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Cada dato lo transformarmos en una matriz de 1 fila 1 columna (1x1)
X_train = np.array(X_train).reshape(len(X_train), len(X_train[0]), 1)
X_test = np.array(X_test).reshape(len(X_test), len(X_test[0]), 1)
print("Dimensiones X_train:", X_train.shape)
print("Dimensiones X_test:", X_test.shape)
# Out:
# Dimensiones X_train: (2393, 8, 1)
# Dimensiones X_test: (599, 8, 1)

# %% [markdown]
# ## Modelo

# %%
input_shape = X_train[0].shape
input_shape
# Out:
# (8, 1)

# %%
output_shape = 1
output_shape
# Out:
# 1

# %%
model = Sequential()
model.add(LSTM(64, activation='sigmoid', return_sequences=True, input_shape=input_shape))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid', return_sequences=True))
model.add(LSTM(64, activation='sigmoid'))
model.add(Dense(output_shape))
model.compile(loss='mse',
              optimizer="Adam")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 8, 64)             16896
#
#  lstm_1 (LSTM)               (None, 8, 64)             33024
#
#  lstm_2 (LSTM)               (None, 8, 64)             33024
#
#  lstm_3 (LSTM)               (None, 8, 64)             33024
#
#  lstm_4 (LSTM)               (None, 8, 64)             33024
#
#  lstm_5 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 182,081
# Trainable params: 182,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=60, validation_split=0.2, batch_size=5)
# Out:
# Epoch 1/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1601 - val_loss: 0.1452
# Epoch 2/60
# 383/383 [==============================] - 5s 14ms/step - loss: 0.1538 - val_loss: 0.1440
# Epoch 3/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1541 - val_loss: 0.1684
# Epoch 4/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1477 - val_loss: 0.1395
# Epoch 5/60
# 383/383 [==============================] - 4s 11ms/step - loss: 0.1460 - val_loss: 0.1826
# Epoch 6/60
# 383/383 [==============================] - 4s 11ms/step - loss: 0.1532 - val_loss: 0.1764
# Epoch 7/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1476 - val_loss: 0.1571
# Epoch 8/60
# 383/383 [==============================] - 6s 14ms/step - loss: 0.1384 - val_loss: 0.1696
# Epoch 9/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1389 - val_loss: 0.1400
# Epoch 10/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1321 - val_loss: 0.1527
# Epoch 11/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1380 - val_loss: 0.1516
# Epoch 12/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1307 - val_loss: 0.1534
# Epoch 13/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1373 - val_loss: 0.1520
# Epoch 14/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1335 - val_loss: 0.1473
# Epoch 15/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1285 - val_loss: 0.1569
# Epoch 16/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1305 - val_loss: 0.1369
# Epoch 17/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1399 - val_loss: 0.1543
# Epoch 18/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1345 - val_loss: 0.1339
# Epoch 19/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1236 - val_loss: 0.1384
# Epoch 20/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1332 - val_loss: 0.1536
# Epoch 21/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1334 - val_loss: 0.1573
# Epoch 22/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1132 - val_loss: 0.1406
# Epoch 23/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1132 - val_loss: 0.1410
# Epoch 24/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1100 - val_loss: 0.1357
# Epoch 25/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1227 - val_loss: 0.1466
# Epoch 26/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1049 - val_loss: 0.1439
# Epoch 27/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1076 - val_loss: 0.1495
# Epoch 28/60
# 383/383 [==============================] - 5s 14ms/step - loss: 0.1035 - val_loss: 0.1404
# Epoch 29/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1190 - val_loss: 0.1400
# Epoch 30/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1037 - val_loss: 0.1654
# Epoch 31/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1130 - val_loss: 0.1420
# Epoch 32/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0993 - val_loss: 0.1358
# Epoch 33/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0844 - val_loss: 0.1566
# Epoch 34/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0820 - val_loss: 0.1710
# Epoch 35/60
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0838 - val_loss: 0.1602
# Epoch 36/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0965 - val_loss: 0.1388
# Epoch 37/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0985 - val_loss: 0.1500
# Epoch 38/60
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0870 - val_loss: 0.1442
# Epoch 39/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0756 - val_loss: 0.1392
# Epoch 40/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0711 - val_loss: 0.1514
# Epoch 41/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0706 - val_loss: 0.1307
# Epoch 42/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0653 - val_loss: 0.1495
# Epoch 43/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0646 - val_loss: 0.1297
# Epoch 44/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0773 - val_loss: 0.1409
# Epoch 45/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0738 - val_loss: 0.1499
# Epoch 46/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0652 - val_loss: 0.1304
# Epoch 47/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0606 - val_loss: 0.1374
# Epoch 48/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0647 - val_loss: 0.1865
# Epoch 49/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0657 - val_loss: 0.1336
# Epoch 50/60
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0958 - val_loss: 0.1650
# Epoch 51/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1238 - val_loss: 0.1521
# Epoch 52/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1066 - val_loss: 0.1467
# Epoch 53/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0641 - val_loss: 0.1332
# Epoch 54/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0545 - val_loss: 0.1207
# Epoch 55/60
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0500 - val_loss: 0.1239
# Epoch 56/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0482 - val_loss: 0.1220
# Epoch 57/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0497 - val_loss: 0.1312
# Epoch 58/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0508 - val_loss: 0.1403
# Epoch 59/60
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0601 - val_loss: 0.1370
# Epoch 60/60
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0531 - val_loss: 0.1204

# %%
# Preformance de Entrenamiento
epoch_count = range(1, len(hist.history['loss']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['loss'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_loss'], label='valid')
plt.show()

# %% [markdown]
# ## Resultados

# %%
y_hat_train = model.predict(X_train, verbose=0)
y_hat_test = model.predict(X_test, verbose=0)

# %%
print("y_hat_train:", y_hat_train.shape)
print("y_hat_test:", y_hat_test.shape)
# Out:
# y_hat_train: (2393, 1)
# y_hat_test: (599, 1)

# %%
arr_tokens = np.array(tokens).reshape(-1,1)
arr_time = np.array(time).reshape(-1,1)

print(arr_tokens.shape)
print(arr_time.shape)
# Out:
# (3001, 1)
# (3001, 1)

# %%
# predicciones del entrenamiento de cambio para plotear
trainPredictPlot = np.empty_like(arr_tokens)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[train_len-1:len(y_hat_train)+train_len-1,:] = y_hat_train

# # predicciones del test de cambio para plotear
testPredictPlot = np.empty_like(arr_tokens)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_hat_train)+(train_len)-1:len(arr_tokens)-1, :] = y_hat_test

print(trainPredictPlot.shape)
print(testPredictPlot.shape)
# Out:
# (3001, 1)
# (3001, 1)

# %%
y_hat_train[0]
# Out:
# array([0.11447963], dtype=float32)

# %%
len(y_hat_train)+(train_len)
# Out:
# 2402

# %%
import plotly.graph_objs as go

import plotly.io as pio
pio.renderers.default = "colab"


def plot_predictions(y, time, y_pred_train, y_pred_test):
    data = []
    
    value = go.Scatter(
        x=time,
        y=y,
        mode="lines",
        name="Ensayo",
        marker=dict(),
        text=time,
        line=dict(color="rgba(0, 0, 250, 0.6)"),
    )
    data.append(value)

    trainPredic = go.Scatter(
        x=time,
        y=y_pred_train,
        mode="lines",
        line=dict(color="orange"),
        name='Predicción set train',
        marker=dict(),
        text=time,
        opacity=0.8,
    )
    data.append(trainPredic)
    
    testPredictions = go.Scatter(
        x=time,
        y=y_pred_test,
        mode="lines",
        line=dict(color="rgba(0, 250, 0, 0.6)"),
        name='Predicción set test',
        marker=dict(),
        text=time,
        opacity=0.8,
    )
    data.append(testPredictions)
    
    layout = dict(
        title='Comparativa de resultados para 176s',
        xaxis=dict(title="tiempo de muestreo (s)", ticklen=5, zeroline=False),
        yaxis=dict(title="desplazamiento ($\mu$m)", ticklen=5, zeroline=False),
    )

    fig = dict(data=data, layout=layout)
    pio.show(fig)
    
    
# Set notebook mode to work in offline
# pyo.init_notebook_mode()
plot_predictions(tokens, time, trainPredictPlot[:,0], testPredictPlot[:,0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f9464970-ea1c-49e8-8480-46226fab10e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9464970-ea1c-49e8-8480-46226fab10e2")) {                    Plotly.newPlot(                        "f9464970-ea1c-49e8-8480-46226fab10e2",                        [{"line":{"color":"rgba(0, 0, 250, 0.6)"},"mode":"lines","name":"Ensayo","text":["176.0","176.00005","176.0001","176.00015","176.0002","176.00024","176.0003","176.00035","176.0004","176.00044","176.0005","176.00055","176.0006","176.00066","176.0007","176.00075","176.0008","176.00085","176.0009","176.00095","176.001","176.00105","176.0011","176.00114","176.0012","176.00125","176.0013","176.00134","176.0014","176.00145","176.0015","176.00156","176.0016","176.00165","176.0017","176.00175","176.0018","176.00185","176.0019","176.00195","176.002","176.00204","176.0021","176.00215","176.0022","176.00224","176.0023","176.00235","176.0024","176.00246","176.0025","176.00255","176.0026","176.00266","176.0027","176.00275","176.0028","176.00285","176.0029","176.00294","176.003","176.00305","176.0031","176.00314","176.0032","176.00325","176.0033","176.00336","176.0034","176.00345","176.0035","176.00356","176.0036","176.00365","176.0037","176.00375","176.0038","176.00385","176.0039","176.00395","176.004","176.00404","176.0041","176.00415","176.0042","176.00426","176.0043","176.00435","176.0044","176.00446","176.0045","176.00455","176.0046","176.00465","176.0047","176.00475","176.0048","176.00485","176.0049","176.00494","176.005","176.00505","176.0051","176.00516","176.0052","176.00525","176.0053","176.00536","176.0054","176.00545","176.0055","176.00555","176.0056","176.00565","176.0057","176.00575","176.0058","176.00584","176.0059","176.00595","176.006","176.00604","176.0061","176.00615","176.0062","176.00626","176.0063","176.00635","176.0064","176.00645","176.0065","176.00655","176.0066","176.00665","176.0067","176.00674","176.0068","176.00685","176.0069","176.00694","176.007","176.00705","176.0071","176.00716","176.0072","176.00725","176.0073","176.00735","176.0074","176.00745","176.0075","176.00755","176.0076","176.00764","176.0077","176.00775","176.0078","176.00784","176.0079","176.00795","176.008","176.00806","176.0081","176.00815","176.0082","176.00826","176.0083","176.00835","176.0084","176.00845","176.0085","176.00854","176.0086","176.00865","176.0087","176.00874","176.0088","176.00885","176.0089","176.00896","176.009","176.00905","176.0091","176.00916","176.0092","176.00925","176.0093","176.00935","176.0094","176.00945","176.0095","176.00955","176.0096","176.00964","176.0097","176.00975","176.0098","176.00986","176.0099","176.00995","176.01","176.01006","176.0101","176.01015","176.0102","176.01025","176.0103","176.01035","176.0104","176.01045","176.0105","176.01054","176.0106","176.01065","176.0107","176.01076","176.0108","176.01085","176.0109","176.01096","176.011","176.01105","176.0111","176.01115","176.0112","176.01125","176.0113","176.01135","176.0114","176.01144","176.0115","176.01155","176.0116","176.01164","176.0117","176.01175","176.0118","176.01186","176.0119","176.01195","176.012","176.01205","176.0121","176.01215","176.0122","176.01225","176.0123","176.01234","176.0124","176.01245","176.0125","176.01254","176.0126","176.01265","176.0127","176.01276","176.0128","176.01285","176.0129","176.01295","176.013","176.01305","176.0131","176.01315","176.0132","176.01324","176.0133","176.01335","176.0134","176.01344","176.0135","176.01355","176.0136","176.01366","176.0137","176.01375","176.0138","176.01385","176.0139","176.01395","176.014","176.01405","176.0141","176.01414","176.0142","176.01425","176.0143","176.01434","176.0144","176.01445","176.0145","176.01456","176.0146","176.01465","176.0147" ...

# %% [markdown]
# ## Comparativa espectral

# %%
y.shape
# Out:
# (2992,)

# %%
fig = plt.figure(figsize=(18, 12))

#------------------
fr_176, A_176 = signal.periodogram(tokens,len(tokens))
arr_sr = np.linspace(0, 10000, len(fr_176), dtype='float32')
ax1 = plt.subplot(311)
ax1.plot(arr_sr, A_176, 'C0')
ax1.set_xlim(arr_sr[0]-10, arr_sr[-1]+10)
ax1.set_ylim(-0.00005, 0.01)
ax1.grid()
ax1.fill_betweenx([-0.00005, 0.01],arr_sr[580], arr_sr[790], color ='tan', alpha = 0.5)
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax1.xaxis.set_major_locator(ticker.MultipleLocator(1000))
# ax1.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax1.set_ylabel('desplazamiento (mm)', fontsize=12)
ax1.set_title(f'Periodograma TS-176', fontsize=14)

#------------------
fr_hat_train, A_hat_train = signal.periodogram(y_hat_train[:,0],len(y_hat_train))
arr_sr_hat_train = np.linspace(0, 10000, len(fr_hat_train), dtype='float32')
ax2 = plt.subplot(312)
ax2.plot(arr_sr_hat_train, A_hat_train, 'C1')
ax2.set_xlim(arr_sr_hat_train[0]-10, arr_sr_hat_train[-1]+10)
ax2.set_ylim(-0.00005, 0.01)
ax2.grid()
ax2.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax2.xaxis.set_major_locator(ticker.MultipleLocator(1000))
# ax2.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax2.set_ylabel('desplazamiento (mm)', fontsize=12)
ax2.set_title(f'Periodograma Set Train', fontsize=14)

#-------------------
fr_hat_test, A_hat_test = signal.periodogram(y_hat_test[:,0],len(y_hat_test))
arr_sr_hat_test = np.linspace(0, 10000, len(fr_hat_test), dtype='float32')
ax3 = plt.subplot(313)
ax3.plot(arr_sr_hat_test, A_hat_test, 'C2')
ax3.set_xlim(arr_sr_hat_test[0]-10, arr_sr_hat_test[-1]+10)
ax3.set_ylim(-0.00005, 0.01)
ax3.grid()
ax3.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax3.xaxis.set_major_locator(ticker.MultipleLocator(1000))
ax3.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax3.set_ylabel('desplazamiento (mm)', fontsize=12)
ax3.set_title(f'Periodograma Set Test', fontsize=14)

plt.show()
