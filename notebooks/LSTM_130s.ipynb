# %% [markdown]
# # # Aplicación de arquitectura LSTM para muestra 130s
# El problema ahora se encarará empleando redes neuronales de tipo _Long Short-Term Memory_ (LSTM).

# %% [markdown]
# ## Librerías necesarias

# %%
# Librerías principales
import os
import numpy as np
import pandas as pd

# Herramientas para graficar
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import Grid
from matplotlib import ticker
import seaborn as sns

from sklearn.model_selection import train_test_split
from scipy import signal

from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.models import Model
from keras.layers import Input


# Versiones de librerías
print("".join(f"{x[0]}: {x[1]}\n" for x in [
    ("Numpy",np.__version__),
    ("Pandas",pd.__version__),
]))
# Out:
# Numpy: 1.21.6
# Pandas: 1.3.5

# %% [markdown]
# ## Carga del dataset
# Se carga un dataset a la vez, como primer prueba

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Colab Notebooks/tsa/data'
files_name = 'dataset_130s.csv'

# %%
df = pd.read_csv(os.path.join(path, files_name), index_col='Time')
df.describe()
# Out:
#          Bearing 1
# count  3001.000000
# mean     -0.000193
# std       0.178277
# min      -0.859000
# 25%      -0.110000
# 50%      -0.002000
# 75%       0.107000
# max       0.815000

# %%
plt.figure(figsize=(20,4))

plt.plot(df.index, df)
plt.xlim(df.index[0], df.index[-1])
plt.grid()
plt.xlabel('tiempo de muestreo (s)', fontsize=12)
plt.ylabel('desplazamiento ($\mu$m)', fontsize=12)
plt.title(f'Vibraciones alrededor de los 100s', fontsize=14)

plt.show()

# %% [markdown]
# ## Preprocesamiento

# %%
tokens = df['Bearing 1'].tolist()
tokens[:10]
# Out:
# [-0.161, -0.315, -0.186, 0.264, 0.405, 0.107, -0.183, -0.068, 0.251, 0.027]

# %%
time = df.index.tolist()
time[:10]
# Out:
# [130.0,
#  130.00005,
#  130.0001,
#  130.00015,
#  130.0002,
#  130.00024,
#  130.0003,
#  130.00035,
#  130.0004,
#  130.00044]

# %%
# Código para hacer el desfazaje de los tokens
# según el train_len
train_len = 15

sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
# sequences[:5]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 2986

# %% [markdown]
# ## Input y Target

# %%
arr_sequences = np.array(sequences)
X = arr_sequences[:,:-1]
y = arr_sequences[:,-1]

print("Dimensiones input:", X.shape)
print("Dimensiones target:", y.shape)
# Out:
# Dimensiones input: (2986, 14)
# Dimensiones target: (2986,)

# %% [markdown]
# ## Preparación

# %%
# Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Cada dato lo transformarmos en una matriz de 1 fila 1 columna (1x1)
X_train = np.array(X_train).reshape(len(X_train), len(X_train[0]), 1)
X_test = np.array(X_test).reshape(len(X_test), len(X_test[0]), 1)
print("Dimensiones X_train:", X_train.shape)
print("Dimensiones X_test:", X_test.shape)
# Out:
# Dimensiones X_train: (2388, 14, 1)
# Dimensiones X_test: (598, 14, 1)

# %% [markdown]
# ## Modelo

# %%
input_shape = X_train[0].shape
input_shape
# Out:
# (14, 1)

# %%
output_shape = 1
output_shape
# Out:
# 1

# %%
model = Sequential()
model.add(LSTM(64, activation='tanh', return_sequences=True, input_shape=input_shape))
model.add(LSTM(64, activation='tanh', return_sequences=True))
model.add(LSTM(64, activation='tanh', return_sequences=True))
model.add(LSTM(64, activation='tanh'))
model.add(Dense(output_shape))
model.compile(loss='mse',
              optimizer="Adam")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 14, 64)            16896
#
#  lstm_1 (LSTM)               (None, 14, 64)            33024
#
#  lstm_2 (LSTM)               (None, 14, 64)            33024
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 116,033
# Trainable params: 116,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=50, validation_split=0.2, batch_size=5)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 14s 13ms/step - loss: 0.0312 - val_loss: 0.0336
# Epoch 2/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0304 - val_loss: 0.0334
# Epoch 3/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0305 - val_loss: 0.0337
# Epoch 4/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0301 - val_loss: 0.0326
# Epoch 5/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0298 - val_loss: 0.0325
# Epoch 6/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0297 - val_loss: 0.0329
# Epoch 7/50
# 382/382 [==============================] - 4s 10ms/step - loss: 0.0296 - val_loss: 0.0322
# Epoch 8/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0294 - val_loss: 0.0321
# Epoch 9/50
# 382/382 [==============================] - 4s 10ms/step - loss: 0.0290 - val_loss: 0.0323
# Epoch 10/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0284 - val_loss: 0.0309
# Epoch 11/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0273 - val_loss: 0.0298
# Epoch 12/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0251 - val_loss: 0.0251
# Epoch 13/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0228 - val_loss: 0.0238
# Epoch 14/50
# 382/382 [==============================] - 4s 11ms/step - loss: 0.0197 - val_loss: 0.0198
# Epoch 15/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0176 - val_loss: 0.0165
# Epoch 16/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0119 - val_loss: 0.0102
# Epoch 17/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0100 - val_loss: 0.0113
# Epoch 18/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 19/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0098 - val_loss: 0.0087
# Epoch 20/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 21/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0094 - val_loss: 0.0093
# Epoch 22/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 23/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 24/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0093 - val_loss: 0.0088
# Epoch 25/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0090 - val_loss: 0.0093
# Epoch 26/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 27/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0090 - val_loss: 0.0095
# Epoch 28/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 29/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0088 - val_loss: 0.0081
# Epoch 30/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0087 - val_loss: 0.0101
# Epoch 31/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0085 - val_loss: 0.0095
# Epoch 32/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 33/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 34/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0083 - val_loss: 0.0098
# Epoch 35/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 36/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0081 - val_loss: 0.0091
# Epoch 37/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 38/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 39/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 40/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 41/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0077 - val_loss: 0.0086
# Epoch 42/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0079 - val_loss: 0.0091
# Epoch 43/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0078 - val_loss: 0.0087
# Epoch 44/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0076 - val_loss: 0.0089
# Epoch 45/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 46/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 47/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 48/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0072 - val_loss: 0.0086
# Epoch 49/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 50/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0072 - val_loss: 0.0082

# %%
# Preformance de Entrenamiento
epoch_count = range(1, len(hist.history['loss']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['loss'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_loss'], label='valid')
plt.show()

# %% [markdown]
# ## Resultados

# %%
y_hat_train = model.predict(X_train, verbose=0)
y_hat_test = model.predict(X_test, verbose=0)

# %%
print("y_hat_train:", y_hat_train.shape)
print("y_hat_test:", y_hat_test.shape)
# Out:
# y_hat_train: (2388, 1)
# y_hat_test: (598, 1)

# %%
arr_tokens = np.array(tokens).reshape(-1,1)
arr_time = np.array(time).reshape(-1,1)

print(arr_tokens.shape)
print(arr_time.shape)
# Out:
# (3001, 1)
# (3001, 1)

# %%
# predicciones del entrenamiento de cambio para plotear
trainPredictPlot = np.empty_like(arr_tokens)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[train_len-1:len(y_hat_train)+train_len-1,:] = y_hat_train

# # predicciones del test de cambio para plotear
testPredictPlot = np.empty_like(arr_tokens)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_hat_train)+(train_len)-1:len(arr_tokens)-1, :] = y_hat_test

print(trainPredictPlot.shape)
print(testPredictPlot.shape)
# Out:
# (3001, 1)
# (3001, 1)

# %%
y_hat_train[0]
# Out:
# array([0.01397883], dtype=float32)

# %%
len(y_hat_train)+(train_len)
# Out:
# 2403

# %%
import plotly.graph_objs as go

import plotly.io as pio
pio.renderers.default = "colab"


def plot_predictions(y, time, y_pred_train, y_pred_test):
    data = []
    
    value = go.Scatter(
        x=time,
        y=y,
        mode="lines",
        name="Ensayo",
        marker=dict(),
        text=time,
        line=dict(color="rgba(0, 0, 250, 0.6)"),
    )
    data.append(value)

    trainPredic = go.Scatter(
        x=time,
        y=y_pred_train,
        mode="lines",
        line=dict(color="orange"),
        name='Predicción set train',
        marker=dict(),
        text=time,
        opacity=0.8,
    )
    data.append(trainPredic)
    
    testPredictions = go.Scatter(
        x=time,
        y=y_pred_test,
        mode="lines",
        line=dict(color="rgba(0, 250, 0, 0.6)"),
        name='Predicción set test',
        marker=dict(),
        text=time,
        opacity=0.8,
    )
    data.append(testPredictions)
    
    layout = dict(
        title='Comparativa de resultados para 130s',
        xaxis=dict(title="tiempo de muestreo (s)", ticklen=5, zeroline=False),
        yaxis=dict(title="desplazamiento ($\mu$m)", ticklen=5, zeroline=False),
    )

    fig = dict(data=data, layout=layout)
    pio.show(fig)
    
    
# Set notebook mode to work in offline
# pyo.init_notebook_mode()
plot_predictions(tokens, time, trainPredictPlot[:,0], testPredictPlot[:,0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8871b9f8-d731-40a8-8de1-916a85eae273" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8871b9f8-d731-40a8-8de1-916a85eae273")) {                    Plotly.newPlot(                        "8871b9f8-d731-40a8-8de1-916a85eae273",                        [{"line":{"color":"rgba(0, 0, 250, 0.6)"},"mode":"lines","name":"Ensayo","text":["130.0","130.00005","130.0001","130.00015","130.0002","130.00024","130.0003","130.00035","130.0004","130.00044","130.0005","130.00055","130.0006","130.00066","130.0007","130.00075","130.0008","130.00085","130.0009","130.00095","130.001","130.00105","130.0011","130.00114","130.0012","130.00125","130.0013","130.00134","130.0014","130.00145","130.0015","130.00156","130.0016","130.00165","130.0017","130.00175","130.0018","130.00185","130.0019","130.00195","130.002","130.00204","130.0021","130.00215","130.0022","130.00224","130.0023","130.00235","130.0024","130.00246","130.0025","130.00255","130.0026","130.00266","130.0027","130.00275","130.0028","130.00285","130.0029","130.00294","130.003","130.00305","130.0031","130.00314","130.0032","130.00325","130.0033","130.00336","130.0034","130.00345","130.0035","130.00356","130.0036","130.00365","130.0037","130.00375","130.0038","130.00385","130.0039","130.00395","130.004","130.00404","130.0041","130.00415","130.0042","130.00426","130.0043","130.00435","130.0044","130.00446","130.0045","130.00455","130.0046","130.00465","130.0047","130.00475","130.0048","130.00485","130.0049","130.00494","130.005","130.00505","130.0051","130.00516","130.0052","130.00525","130.0053","130.00536","130.0054","130.00545","130.0055","130.00555","130.0056","130.00565","130.0057","130.00575","130.0058","130.00584","130.0059","130.00595","130.006","130.00604","130.0061","130.00615","130.0062","130.00626","130.0063","130.00635","130.0064","130.00645","130.0065","130.00655","130.0066","130.00665","130.0067","130.00674","130.0068","130.00685","130.0069","130.00694","130.007","130.00705","130.0071","130.00716","130.0072","130.00725","130.0073","130.00735","130.0074","130.00745","130.0075","130.00755","130.0076","130.00764","130.0077","130.00775","130.0078","130.00784","130.0079","130.00795","130.008","130.00806","130.0081","130.00815","130.0082","130.00826","130.0083","130.00835","130.0084","130.00845","130.0085","130.00854","130.0086","130.00865","130.0087","130.00874","130.0088","130.00885","130.0089","130.00896","130.009","130.00905","130.0091","130.00916","130.0092","130.00925","130.0093","130.00935","130.0094","130.00945","130.0095","130.00955","130.0096","130.00964","130.0097","130.00975","130.0098","130.00986","130.0099","130.00995","130.01","130.01006","130.0101","130.01015","130.0102","130.01025","130.0103","130.01035","130.0104","130.01045","130.0105","130.01054","130.0106","130.01065","130.0107","130.01076","130.0108","130.01085","130.0109","130.01096","130.011","130.01105","130.0111","130.01115","130.0112","130.01125","130.0113","130.01135","130.0114","130.01144","130.0115","130.01155","130.0116","130.01164","130.0117","130.01175","130.0118","130.01186","130.0119","130.01195","130.012","130.01205","130.0121","130.01215","130.0122","130.01225","130.0123","130.01234","130.0124","130.01245","130.0125","130.01254","130.0126","130.01265","130.0127","130.01276","130.0128","130.01285","130.0129","130.01295","130.013","130.01305","130.0131","130.01315","130.0132","130.01324","130.0133","130.01335","130.0134","130.01344","130.0135","130.01355","130.0136","130.01366","130.0137","130.01375","130.0138","130.01385","130.0139","130.01395","130.014","130.01405","130.0141","130.01414","130.0142","130.01425","130.0143","130.01434","130.0144","130.01445","130.0145","130.01456","130.0146","130.01465","130.0147" ...

# %% [markdown]
# ## Comparativa espectral

# %%
y.shape
# Out:
# (2986,)

# %%
fig = plt.figure(figsize=(18, 12))

#------------------
fr_130, A_130 = signal.periodogram(tokens,len(tokens))
arr_sr = np.linspace(0, 10000, len(fr_130), dtype='float32')
ax1 = plt.subplot(311)
ax1.plot(arr_sr, A_130, 'C0')
ax1.set_xlim(arr_sr[0]-10, arr_sr[-1]+10)
ax1.set_ylim(-0.00005, 0.003)
ax1.grid()
ax1.fill_betweenx([-0.00005, 0.003],arr_sr[600], arr_sr[750], color ='tan', alpha = 0.5)
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax1.xaxis.set_major_locator(ticker.MultipleLocator(1000))
# ax1.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax1.set_ylabel('desplazamiento (mm)', fontsize=12)
ax1.set_title(f'Periodograma TS-130', fontsize=14)

#------------------
fr_hat_train, A_hat_train = signal.periodogram(y_hat_train[:,0],len(y_hat_train))
arr_sr_hat_train = np.linspace(0, 10000, len(fr_hat_train), dtype='float32')
ax2 = plt.subplot(312)
ax2.plot(arr_sr_hat_train, A_hat_train, 'C1')
ax2.set_xlim(arr_sr_hat_train[0]-10, arr_sr_hat_train[-1]+10)
ax2.set_ylim(-0.00005, 0.003)
ax2.grid()
ax2.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax2.xaxis.set_major_locator(ticker.MultipleLocator(1000))
# ax2.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax2.set_ylabel('desplazamiento (mm)', fontsize=12)
ax2.set_title(f'Periodograma Set Train', fontsize=14)

#-------------------
fr_hat_test, A_hat_test = signal.periodogram(y_hat_test[:,0],len(y_hat_test))
arr_sr_hat_test = np.linspace(0, 10000, len(fr_hat_test), dtype='float32')
ax3 = plt.subplot(313)
ax3.plot(arr_sr_hat_test, A_hat_test, 'C2')
ax3.set_xlim(arr_sr_hat_test[0]-10, arr_sr_hat_test[-1]+10)
ax3.set_ylim(-0.00005, 0.0055)
ax3.grid()
ax3.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax3.xaxis.set_major_locator(ticker.MultipleLocator(1000))
ax3.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax3.set_ylabel('desplazamiento (mm)', fontsize=12)
ax3.set_title(f'Periodograma Set Test', fontsize=14)

plt.show()
