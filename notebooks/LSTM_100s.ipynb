# %% [markdown]
# # Aplicación de arquitectura LSTM para muestra 100s
# El problema ahora se encarará empleando redes neuronales de tipo _Long Short-Term Memory_ (LSTM).

# %% [markdown]
# ## Librerías necesarias

# %%
# Librerías principales
import os
import numpy as np
import pandas as pd

# Herramientas para graficar
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import Grid
from matplotlib import ticker
import seaborn as sns

from sklearn.model_selection import train_test_split
from scipy import signal

from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.models import Model
from keras.layers import Input


# Versiones de librerías
print("".join(f"{x[0]}: {x[1]}\n" for x in [
    ("Numpy",np.__version__),
    ("Pandas",pd.__version__),
]))
# Out:
# Numpy: 1.21.6
# Pandas: 1.3.5

# %% [markdown]
# ## Sliding Window
# Se hace un modelo de juguete para visualizar cómo funciona el algoritmo

# %%
a = [x for x in range(0, 30, 1)]

# %% [markdown]
# Se empieza por mostrar cómo se comporta una configuración tipo _sliding window_

# %%
# largo de la secuencia, incluye input + output
train_len = 4

seq_w = []
for i in range(train_len, len(a)):
  seq = a[i-train_len:i]
  seq_w.append(seq)

# %%
seq_w[:3]
# Out:
# [[0, 1, 2, 3], [1, 2, 3, 4], [2, 3, 4, 5]]

# %%
seq_w = np.array(seq_w)
input_w = seq_w[:,:-1] # todos los rows, menos la ultima col
target_w = seq_w[:, -1] # última col de cada row

print("Input_w (primeras 3 filas):", input_w[:3])
print("Target_w (primeros 3 valores):", target_w[:3])
# Out:
# Input_w (primeras 3 filas): [[0 1 2]
#  [1 2 3]
#  [2 3 4]]
# Target_w (primeros 3 valores): [3 4 5]

# %% [markdown]
# ## Carga del dataset
# Se carga un dataset a la vez, como primer prueba

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/tsa/data'
files_name = 'dataset_100s.csv'

# %%
df = pd.read_csv(os.path.join(path, files_name), index_col='Time')
df.describe()
# Out:
#          Bearing 1
# count  3000.000000
# mean     -0.003400
# std       0.124253
# min      -0.564000
# 25%      -0.078000
# 50%      -0.005000
# 75%       0.071000
# max       0.566000

# %%
plt.figure(figsize=(20,4))

plt.plot(df.index, df)
plt.xlim(df.index[0], df.index[-1])
plt.grid()
plt.xlabel('tiempo de muestreo (s)', fontsize=12)
plt.ylabel('desplazamiento ($\mu$m)', fontsize=12)
plt.title(f'Vibraciones alrededor de los 100s', fontsize=14)

plt.show()

# %% [markdown]
# ## Preprocesamiento

# %%
tokens = df['Bearing 1'].tolist()
tokens[:10]
# Out:
# [-0.161, -0.073, -0.01, -0.037, -0.061, -0.027, 0.032, 0.037, 0.046, 0.139]

# %%
time = df.index.tolist()
time[:10]
# Out:
# [100.0,
#  100.00005,
#  100.0001,
#  100.00015,
#  100.0002,
#  100.00025,
#  100.0003,
#  100.00035,
#  100.0004,
#  100.00045]

# %%
# Código para hacer el desfazaje de los tokens
# según el train_len
train_len = 20

sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
# sequences[:5]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 2980

# %% [markdown]
# ## Input y Target

# %%
arr_sequences = np.array(sequences)
X = arr_sequences[:,:-1]
y = arr_sequences[:,-1]

print("Dimensiones input:", X.shape)
print("Dimensiones target:", y.shape)
# Out:
# Dimensiones input: (2980, 19)
# Dimensiones target: (2980,)

# %% [markdown]
# ## Preparación

# %%
# Separación en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Cada dato lo transformarmos en una matriz de 1 fila 1 columna (1x1)
X_train = np.array(X_train).reshape(len(X_train), len(X_train[0]), 1)
X_test = np.array(X_test).reshape(len(X_test), len(X_test[0]), 1)
print("Dimensiones X_train:", X_train.shape)
print("Dimensiones X_test:", X_test.shape)
# Out:
# Dimensiones X_train: (2384, 19, 1)
# Dimensiones X_test: (596, 19, 1)

# %% [markdown]
# ## Modelo

# %%
input_shape = X_train[0].shape
input_shape
# Out:
# (19, 1)

# %%
output_shape = 1
output_shape
# Out:
# 1

# %%
model = Sequential()
model.add(LSTM(128, activation='tanh', return_sequences=True, input_shape=input_shape))
model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(LSTM(128, activation='tanh'))
model.add(Dense(output_shape))
model.compile(loss='mse',
              optimizer="Adam")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 19, 128)           66560
#
#  lstm_1 (LSTM)               (None, 19, 128)           131584
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 329,857
# Trainable params: 329,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=50, validation_split=0.2, batch_size=5)
# Out:
# Epoch 1/50
# 382/382 [==============================] - 13s 11ms/step - loss: 0.0148 - val_loss: 0.0168
# Epoch 2/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0148 - val_loss: 0.0161
# Epoch 3/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0145 - val_loss: 0.0160
# Epoch 4/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0145 - val_loss: 0.0162
# Epoch 5/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0133 - val_loss: 0.0087
# Epoch 6/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0075 - val_loss: 0.0092
# Epoch 7/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0074 - val_loss: 0.0083
# Epoch 8/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0073 - val_loss: 0.0082
# Epoch 9/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 10/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0073 - val_loss: 0.0085
# Epoch 11/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0072 - val_loss: 0.0079
# Epoch 12/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 13/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0072 - val_loss: 0.0078
# Epoch 14/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0071 - val_loss: 0.0081
# Epoch 15/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 16/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0070 - val_loss: 0.0084
# Epoch 17/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 18/50
# 382/382 [==============================] - 4s 9ms/step - loss: 0.0069 - val_loss: 0.0078
# Epoch 19/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 20/50
# 382/382 [==============================] - 4s 9ms/step - loss: 0.0070 - val_loss: 0.0076
# Epoch 21/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0068 - val_loss: 0.0070
# Epoch 22/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0068 - val_loss: 0.0076
# Epoch 23/50
# 382/382 [==============================] - 4s 9ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 24/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 25/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0065 - val_loss: 0.0072
# Epoch 26/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 27/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 28/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0063 - val_loss: 0.0065
# Epoch 29/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 30/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 31/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 32/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0059 - val_loss: 0.0064
# Epoch 33/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0059 - val_loss: 0.0069
# Epoch 34/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0058 - val_loss: 0.0065
# Epoch 35/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0057 - val_loss: 0.0072
# Epoch 36/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0057 - val_loss: 0.0064
# Epoch 37/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0056 - val_loss: 0.0066
# Epoch 38/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0055 - val_loss: 0.0067
# Epoch 39/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0055 - val_loss: 0.0064
# Epoch 40/50
# 382/382 [==============================] - 3s 9ms/step - loss: 0.0054 - val_loss: 0.0066
# Epoch 41/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 42/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0053 - val_loss: 0.0072
# Epoch 43/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0053 - val_loss: 0.0073
# Epoch 44/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0052 - val_loss: 0.0064
# Epoch 45/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0050 - val_loss: 0.0071
# Epoch 46/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 47/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 48/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 49/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0048 - val_loss: 0.0066
# Epoch 50/50
# 382/382 [==============================] - 3s 8ms/step - loss: 0.0048 - val_loss: 0.0068

# %%
# Preformance de Entrenamiento
epoch_count = range(1, len(hist.history['loss']) + 1)
sns.lineplot(x=epoch_count,  y=hist.history['loss'], label='train')
sns.lineplot(x=epoch_count,  y=hist.history['val_loss'], label='valid')
plt.show()

# %% [markdown]
# ## Resultados

# %%
y_hat_train = model.predict(X_train, verbose=0)
y_hat_test = model.predict(X_test, verbose=0)

# %%
print("y_hat_train:", y_hat_train.shape)
print("y_hat_test:", y_hat_test.shape)
# Out:
# y_hat_train: (2384, 1)
# y_hat_test: (596, 1)

# %%
arr_tokens = np.array(tokens).reshape(-1,1)
arr_time = np.array(time).reshape(-1,1)

print(arr_tokens.shape)
print(arr_time.shape)
# Out:
# (3000, 1)
# (3000, 1)

# %%
# predicciones del entrenamiento de cambio para plotear
trainPredictPlot = np.empty_like(arr_tokens)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[train_len-1:len(y_hat_train)+train_len-1,:] = y_hat_train

# # predicciones del test de cambio para plotear
testPredictPlot = np.empty_like(arr_tokens)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(y_hat_train)+(train_len)-2:len(arr_tokens)-2, :] = y_hat_test

print(trainPredictPlot.shape)
print(testPredictPlot.shape)
# Out:
# (3000, 1)
# (3000, 1)

# %%
y_hat_train[0]
# Out:
# array([-0.08180811], dtype=float32)

# %%
len(y_hat_train)+(train_len)
# Out:
# 2404

# %%
import plotly.graph_objs as go

import plotly.io as pio
pio.renderers.default = "colab"


def plot_predictions(y, time, y_pred_train, y_pred_test):
    data = []
    
    value = go.Scatter(
        x=time,
        y=y,
        mode="lines",
        name="Ensayo",
        marker=dict(),
        text=time,
        line=dict(color="rgba(0, 0, 250, 0.6)"),
    )
    data.append(value)

    trainPredic = go.Scatter(
        x=time,
        y=y_pred_train,
        mode="lines",
        line=dict(color="orange"),
        name='Predicción set train',
        marker=dict(),
        text=time,
        opacity=0.8,
    )
    data.append(trainPredic)
    
    testPredictions = go.Scatter(
        x=time,
        y=y_pred_test,
        mode="lines",
        line=dict(color="rgba(0, 250, 0, 0.6)"),
        name='Predicción set test',
        marker=dict(),
        text=time,
        opacity=0.8,
    )
    data.append(testPredictions)
    
    layout = dict(
        title='Comparativa de resultados para 100s',
        xaxis=dict(title="tiempo de muestreo (s)", ticklen=5, zeroline=False),
        yaxis=dict(title="desplazamiento ($\mu$m)", ticklen=5, zeroline=False),
    )

    fig = dict(data=data, layout=layout)
    pio.show(fig)
    
    
# Set notebook mode to work in offline
# pyo.init_notebook_mode()
plot_predictions(tokens, time, trainPredictPlot[:,0], testPredictPlot[:,0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7daf3203-f165-4d34-9dd5-267c43a11142" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7daf3203-f165-4d34-9dd5-267c43a11142")) {                    Plotly.newPlot(                        "7daf3203-f165-4d34-9dd5-267c43a11142",                        [{"line":{"color":"rgba(0, 0, 250, 0.6)"},"mode":"lines","name":"Ensayo","text":["100.0","100.00005","100.0001","100.00015","100.0002","100.00025","100.0003","100.00035","100.0004","100.00045","100.0005","100.00055","100.0006","100.00065","100.0007","100.00075","100.0008","100.00085","100.0009","100.00095","100.001","100.00105","100.0011","100.00115","100.0012","100.00125","100.0013","100.00135","100.0014","100.00145","100.0015","100.00155","100.0016","100.00165","100.0017","100.00175","100.0018","100.00185","100.0019","100.00195","100.002","100.00205","100.0021","100.00215","100.0022","100.00225","100.0023","100.00235","100.0024","100.00245","100.0025","100.00255","100.0026","100.00265","100.0027","100.00275","100.0028","100.00285","100.0029","100.00295","100.003","100.00305","100.0031","100.00315","100.0032","100.00325","100.0033","100.00335","100.0034","100.00345","100.0035","100.00355","100.0036","100.00365","100.0037","100.00375","100.0038","100.00385","100.0039","100.00395","100.004","100.00405","100.0041","100.00415","100.0042","100.00425","100.0043","100.00435","100.0044","100.00445","100.0045","100.00455","100.0046","100.00465","100.0047","100.00475","100.0048","100.00485","100.0049","100.00495","100.005","100.00505","100.0051","100.00515","100.0052","100.00525","100.0053","100.00535","100.0054","100.00545","100.0055","100.00555","100.0056","100.00565","100.0057","100.00575","100.0058","100.00585","100.0059","100.00595","100.006","100.00605","100.0061","100.00615","100.0062","100.00625","100.0063","100.00635","100.0064","100.00645","100.0065","100.00655","100.0066","100.00665","100.0067","100.00675","100.0068","100.00685","100.0069","100.00695","100.007","100.00705","100.0071","100.00715","100.0072","100.00725","100.0073","100.00735","100.0074","100.00745","100.0075","100.00755","100.0076","100.00765","100.0077","100.00775","100.0078","100.00785","100.0079","100.00795","100.008","100.00805","100.0081","100.00815","100.0082","100.00825","100.0083","100.00835","100.0084","100.00845","100.0085","100.00855","100.0086","100.00865","100.0087","100.00875","100.0088","100.00885","100.0089","100.00895","100.009","100.00905","100.0091","100.00915","100.0092","100.00925","100.0093","100.00935","100.0094","100.00945","100.0095","100.00955","100.0096","100.00965","100.0097","100.00975","100.0098","100.00985","100.0099","100.00995","100.01","100.01005","100.0101","100.01015","100.0102","100.01025","100.0103","100.01035","100.0104","100.01045","100.0105","100.01055","100.0106","100.01065","100.0107","100.01075","100.0108","100.01085","100.0109","100.01095","100.011","100.01105","100.0111","100.01115","100.0112","100.01125","100.0113","100.01135","100.0114","100.01145","100.0115","100.01155","100.0116","100.01165","100.0117","100.01175","100.0118","100.01185","100.0119","100.01195","100.012","100.01205","100.0121","100.01215","100.0122","100.01225","100.0123","100.01235","100.0124","100.01245","100.0125","100.01255","100.0126","100.01265","100.0127","100.01275","100.0128","100.01285","100.0129","100.01295","100.013","100.01305","100.0131","100.01315","100.0132","100.01325","100.0133","100.01335","100.0134","100.01345","100.0135","100.01355","100.0136","100.01365","100.0137","100.01375","100.0138","100.01385","100.0139","100.01395","100.014","100.01405","100.0141","100.01415","100.0142","100.01425","100.0143","100.01435","100.0144","100.01445","100.0145","100.01455","100.0146","100.01465","100.0147" ...

# %% [markdown]
# ## Comparativa espectral

# %%
y.shape
# Out:
# (2980,)

# %%
fig = plt.figure(figsize=(18, 12))

#------------------
fr_100, A_100 = signal.periodogram(tokens,len(tokens))
arr_sr = np.linspace(0, 10000, len(fr_100), dtype='float32')
ax1 = plt.subplot(311)
ax1.plot(arr_sr, A_100, 'C0')
ax1.set_xlim(arr_sr[0]-10, arr_sr[-1]+10)
ax1.set_ylim(-0.00003, 0.001)
ax1.grid()
ax1.fill_betweenx([-0.00003, 0.001],arr_sr[420], arr_sr[780], color ='tan', alpha = 0.5)
ax1.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax1.xaxis.set_major_locator(ticker.MultipleLocator(1000))
# ax1.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax1.set_ylabel('desplazamiento (mm)', fontsize=12)
ax1.set_title(f'Periodograma TS-100', fontsize=14)

#------------------
fr_hat_train, A_hat_train = signal.periodogram(y_hat_train[:,0],len(y_hat_train))
arr_sr_hat_train = np.linspace(0, 10000, len(fr_hat_train), dtype='float32')
ax2 = plt.subplot(312)
ax2.plot(arr_sr_hat_train, A_hat_train, 'C1')
ax2.set_xlim(arr_sr_hat_train[0]-10, arr_sr_hat_train[-1]+10)
ax2.set_ylim(-0.00003, 0.001)
ax2.grid()
ax2.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax2.xaxis.set_major_locator(ticker.MultipleLocator(1000))
# ax2.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax2.set_ylabel('desplazamiento (mm)', fontsize=12)
ax2.set_title(f'Periodograma Set Train', fontsize=14)

#-------------------
fr_hat_test, A_hat_test = signal.periodogram(y_hat_test[:,0],len(y_hat_test))
arr_sr_hat_test = np.linspace(0, 10000, len(fr_hat_test), dtype='float32')
ax3 = plt.subplot(313)
ax3.plot(arr_sr_hat_test, A_hat_test, 'C2')
ax3.set_xlim(arr_sr_hat_test[0]-10, arr_sr_hat_test[-1]+10)
ax3.set_ylim(-0.00003, 0.001)
ax3.grid()
ax3.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax3.xaxis.set_major_locator(ticker.MultipleLocator(1000))
ax3.set_xlabel('Tasa de muestreo (Hz)', fontsize=12)
ax3.set_ylabel('desplazamiento (mm)', fontsize=12)
ax3.set_title(f'Periodograma Set Test', fontsize=14)

plt.show()
